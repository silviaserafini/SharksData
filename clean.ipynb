# %%
import pandas as pd

data = pd.read_csv (r"/Users/silviaserafini/Desktop/attacks.csv",encoding='latin-1')
df = pd.DataFrame(data)
display(df.head())
print(df.shape)
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F
# 2                    Habush, Oahu      Surfing      John Denges    M
# 3              Arrawarra Headland      Surfing             male    M
# 4                        La Ticla  Free diving   Gustavo Ramos     M
#
#       ...             Species           Investigator or Source  \
# 0     ...          White shark                R. Collier, GSAF
# 1     ...                  NaN  K.McMurray, TrackingSharks.com
# 2     ...                  NaN  K.McMurray, TrackingSharks.com
# 3     ...            2 m shark                  B. Myatt, GSAF
# 4     ...      Tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                         href formula  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                 href Case Number.1  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.25
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.18
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.09
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.08
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...    2018.06.04
#
#   Case Number.2 original order Unnamed: 22 Unnamed: 23
# 0    2018.06.25         6303.0         NaN         NaN
# 1    2018.06.18         6302.0         NaN         NaN
# 2    2018.06.09         6301.0         NaN         NaN
# 3    2018.06.08         6300.0         NaN         NaN
# 4    2018.06.04         6299.0         NaN         NaN
#
# [5 rows x 24 columns]
# (25723, 24)

# %%
#inspection of the names of the columns
df.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
#dropping unusefull columns
df=df.drop(['Investigator or Source', 'pdf', 'href formula', 'href',
       'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
       'Unnamed: 23'],axis=1)

#dropping unusefull rows    
df_clean=df.dropna(axis=0, how='all', thresh=None, subset=None, inplace=False)

#removing of eventual duplicates
df_clean=df_clean.drop_duplicates()

# %%
print(df_clean.shape)
# Out:
# (6304, 15)

# %%
nulle=df_clean["Fatal (Y/N)"].isnull().sum()
notNulle=df_clean["Fatal (Y/N)"].count()
perc=notNulle/(nulle+notNulle)
print(perc)
print(nulle)
print(notNulle)
print(nulle+notNulle)
# Out:
# 0.914181472081
# 541
# 5763
# 6304

# %%
#trying to fill in the empty cells of the 'Year' column by inserting the year found with a regex in the same row, Date column

import re

#fn = lambda txt: re.findall(r'[0-9]{4}',str(txt)[0] if re.findall(r'[0-9]{4}', str(txt) else 'unknown'

def fn(txt):
    txt=str(txt)
    if re.findall(r'[0-9]{4}',txt):
        return re.findall(r'[0-9]{4}',txt)[0]
    else :
        return 'unknown'

#Storage of the guessed year on a temporary support column 'DataTent'                                                                                                                            
df_clean['DateTent']=df_clean['Date'].apply(fn)

#replace the value of DataTent in Year isnull cells
df_clean.loc[df_clean['Year'].isnull(),"Year"] = df_clean['DateTent'][df_clean['Year'].isnull()]

#replace value Year == 0 or Year==unknown
for i in range(df_clean.shape[0]):
    if df_clean.iloc[i][2]== '0' or df_clean.iloc[i][2]== 'unknown':
        df_clean.iloc[i][2]= df_clean.iloc[i][15]                                                 

#value check of column year: keep only valid years
df_clean['Year']=df_clean['Year'].apply(fn)

#print("count of null values=",df_clean['Year'].isnull().sum())

#df_clean=df_clean.reset_index().sort_values("index").set_index('index').Year                                            
#hand change of 2 values:
df_clean.loc[df_clean["Year"].str.startswith("W"),"Year"] = "1939"                                                          

#Drop dataTent column
df_clean=df_clean.drop('DateTent', axis=1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#drop the last rows with unknown year. These cases are very old and not relevant for the analysis 


filter1 = []
for result in df_clean.Year:
    if not re.search('unknown', result):
        filter1.append(True)
    else:
        filter1.append(False)

#display(df_clean[filter1])

df_clean=df_clean[filter1]
print(df_clean.Year.sort_values().value_counts())
# Out:
# 2015    143
# 2017    137
# 2016    130
# 2011    128
# 2014    127
# 2013    122
# 2008    122
# 2009    120
# 2012    117
# 2007    112
# 2005    103
# 2006    103
# 2010    101
# 2000     97
# 1960     93
# 1959     93
# 2004     92
# 2003     92
# 2001     92
# 2002     88
# 1962     86
# 1961     78
# 1995     76
# 1999     66
# 1964     66
# 1998     65
# 1996     61
# 1963     61
# 1966     58
# 1997     57
#        ...
# 1638      1
# 1784      1
# 1791      1
# 1783      1
# 1543      1
# 1767      1
# 1804      1
# 1792      1
# 1748      1
# 1859      1
# 1807      1
# 1742      1
# 1857      1
# 1802      1
# 1755      1
# 1801      1
# 1723      1
# 1555      1
# 1787      1
# 1810      1
# 1721      1
# 1779      1
# 1733      1
# 1554      1
# 1797      1
# 1749      1
# 1703      1
# 1637      1
# 1738      1
# 1764      1
# Name: Year, Length: 245, dtype: int64

# %%
df_clean=df_clean.sort_values(by=['Year','Date'], ascending=False, na_position='first')

# %%
#cleaning of Type column
print(df_clean.isnull().sum())
df_clean.Type.value_counts()
# Out:
# Case Number       1
# Date              0
# Year              0
# Type              4
# Country          45
# Area            428
# Location        504
# Activity        524
# Name            205
# Sex             557
# Age            2716
# Injury           27
# Fatal (Y/N)     538
# Time           3233
# Species        2745
# dtype: int64
# Unprovoked      4484
# Provoked         567
# Invalid          545
# Sea Disaster     233
# Boating          203
# Boat             135
# Questionable       2
# Boatomg            1
# Name: Type, dtype: int64

# %%
#what does 'invalid means?'
df_clean.loc[df_clean.Type=='Invalid']

#I can drop these rows,sharks involvement is unconfirmed 
df_clean=df_clean.loc[(df_clean.Type!='Invalid') & (df_clean.Type!='Questionable')]
#recategorization
df_clean['Type']=df_clean['Type'].replace(['Boat','Boatomg'],'Boating')

# %%
#recategorization
df_clean['Type']=df_clean['Type'].replace('Sea Disaster','Unprovoked')

# %%
#replacement of the null values with the mostfrequent category value
df_clean['Type'].isnull().sum()
df_clean[df_clean['Type'].isnull()]
df_clean['Type'].describe()
df_clean[df_clean['Type'].isnull()]=df_clean[df_clean['Type'].isnull()].fillna('Unprovoked')
df_clean['Type'].isnull().sum()
# Out:
# 0

# %%
#creation of 2 dummies variables for Type

# %%
#claning of column Fatal (Y/N)
df_clean.head()
df_clean['Fatal (Y/N)'].isnull().sum()
# Out:
# 14

# %%
df_clean[df_clean['Fatal (Y/N)'].isnull()]

def fn1(x):
    if re.findall('FATAL',str(x).upper()) or re.findall('drowning',str(x)) :
        return 'Y'
    else:
        return 'N'
    
res=df_clean.loc[df_clean['Fatal (Y/N)'].isnull()]['Fatal (Y/N)'].apply(fn1)
display(res)
# Out:
# 27      N
# 294     N
# 269     N
# 1292    N
# 3452    N
# 3506    N
# 4127    N
# 4333    N
# 6125    N
# 5630    N
# 5945    N
# 6104    N
# 6122    N
# 6158    N
# Name: Fatal (Y/N), dtype: object

# %%
df_clean.head()
# Out:
#      Case Number                  Date  Year        Type    Country  \
# 17  2018.04.30.R  Reported 30-Apr-2018  2018  Unprovoked   THAILAND
# 14    2018.05.00              May 2018  2018    Provoked  AUSTRALIA
# 37  2018.03.09.b            9-Mar-2018  2018  Unprovoked  AUSTRALIA
# 38  2018.03.09.a            9-Mar-2018  2018  Unprovoked  AUSTRALIA
# 35    2018.03.31           31-Mar-2018  2018  Unprovoked        USA
#
#                  Area       Location                 Activity  \
# 17            Hua Hin  Sai Noi Beach                 Swimming
# 14  Westerm Australia     Dugong Bay           Feeding sharks
# 37           Victoria          Lorne                 Swimming
# 38           Victoria       Winkipop                  Surfing
# 35             Hawaii    Kukio Beach  Stand-Up Paddleboarding
#
#                Name Sex   Age  \
# 17           female    M  NaN
# 14  Melisa Brunning    F   34
# 37    Rob Crossland    M   69
# 38     Lachie Brown    M   18
# 35             male    M   25
#
#                                                Injury Fatal (Y/N)   Time  \
# 17                              Minor injury to ankle           N    NaN
# 14    Shallow lacerations to finger PROVOKED INCIDENT           N    NaN
# 37  No injury, said to have been charged by sharks...           N  15h30
# 38                         Minor injury, ankle grazed           N  07h30
# 35                       Injuries to right leg & hand           N  09h30
#
#                  Species
# 17                    NaN
# 14  Tawny nurse shark, 2m
# 37            3.5 m shark
# 38            1.8 m shark
# 35       Tiger shark, 12'

# %%
df_clean['Country'].value_counts()
df_clean['Country'].isnull().sum()
df_analysis=df_clean.fillna('unknown')
df_analysis.replace('unkown','unknown')
# Out:
#        Case Number                      Date  Year        Type  \
# 17    2018.04.30.R      Reported 30-Apr-2018  2018  Unprovoked
# 14      2018.05.00                  May 2018  2018    Provoked
# 37    2018.03.09.b                9-Mar-2018  2018  Unprovoked
# 38    2018.03.09.a                9-Mar-2018  2018  Unprovoked
# 35      2018.03.31               31-Mar-2018  2018  Unprovoked
# 47      2018.01.28               28-Jan-2018  2018  Unprovoked
# 18    2018.04.28.b               28-Apr-2018  2018  Unprovoked
# 19    2018.04.28.a               28-Apr-2018  2018  Unprovoked
# 7       2018.05.27               27-May-2018  2018  Unprovoked
# 8     2018.05.26.b               26-May-2018  2018  Unprovoked
# 9     2018.05.26.a               26-May-2018  2018  Unprovoked
# 0       2018.06.25               25-Jun-2018  2018     Boating
# 21    2018.04.25.a               25-Apr-2018  2018  Unprovoked
# 10      2018.05.24               24-May-2018  2018    Provoked
# 39      2018.02.24               24-Feb-2018  2018  Unprovoked
# 22      2018.04.24               24-Apr-2018  2018  Unprovoked
# 40      2018.02.23               23-Feb-2018  2018  Unprovoked
# 23      2018.04.23               23-Apr-2018  2018  Unprovoked
# 24      2018.04.22               22-Apr-2018  2018  Unprovoked
# 11      2018.05.21               21-May-2018  2018  Unprovoked
# 48      2018.01.21               21-Jan-2018  2018  Unprovoked
# 25      2018.04.19               19-Apr-2018  2018  Unprovoked
# 1       2018.06.18               18-Jun-2018  2018  Unprovoked
# 41      2018.02.17               18-Feb-2018  2018    Provoked
# 42      2018.02.15               15-Feb-2018  2018  Unprovoked
# 26    2018.04.15.d               15-Apr-2018  2018  Unprovoked
# 27    2018.04.15.c               15-Apr-2018  2018  Unprovoked
# 28    2018.04.15.b               15-Apr-2018  2018  Unprovoked
# 29    2018.04.15.a               15-Apr-2018  2018  Unprovoked
# 36      2018.03.14               14-Mar-2018  2018  Unprovoked
# ...            ...                       ...   ...         ...
# 6141    1783.03.02               02-Mar-1783  1783  Unprovoked
# 6142    1780.08.08               08-Aug-1780  1780  Unprovoked
# 6143    1779.00.00                      1779  1779  Unprovoked
# 6144  1776.00.00.R             Reported 1776  1776  Unprovoked
# 6145  1776.00.00.b                      1776  1776     Boating
# 6146  1771.07.12.R      Reported 12-Jul-1771  1771  Unprovoked
# 6148    1764.00.00                      1764  1764  Unprovoked
# 6149    1758.00.00                      1758  1758  Unprovoked
# 6153    1755.00.00                      1755  1755  Unprovoked
# 6150  1753.10.27.R      Reported 27-Oct-1753  1753  Unprovoked
# 6151    1751.07.27               27-Jul-1751  1751  Unprovoked
# 6152    1749.00.00                      1749  1749  Unprovoked
# 6154    1748.00.00                      1748  1748  Unprovoked
# 6155    1742.12.17               17-Dec-1742  1742  Unprovoked
# 6156  1738.04.06.R      Reported 06-Apr-1738  1738  Unprovoked
# 6158    1723.00.00                      1723  1723  Unprovoked
# 6159    1721.06.00                 June 1721  1721  Unprovoked
# 6160    1703.03.26               26-Mar-1703  1703  Unprovoked
# 6161  1700.00.00.c                     1700s  1700  Unprovoked
# 6162  1700.00.00.b                     1700s  1700  Unprovoked
# 6163  1700.00.00.a                     1700s  1700  Unprovoked
# 6168    1642.00.00                      1642  1642  Unprovoked
# 6165  1638.00.00.R             Reported 1638  1638  Unprovoked
# 6166  1637.00.00.R             Reported 1637  1637  Unprovoked
# 6167  1617.00.00.R             Reported 1617  1617  Unprovoked
# 6169    1595.00.00                      1595  1595  Unprovoked
# 6170  1580.01.10.R  Letter dated 10-Jan-1580  1580  Unprovoked
# 6171    1555.00.00                      1555  1555  Unprovoked
# 6172    1554.00.00                  Ca. 1554  1554  Unprovoked
# 6173    1543.00.00                  Ca. 1543  1543  Unprovoked
#
#                        Country                            Area  \
# 17                    THAILAND                         Hua Hin
# 14                   AUSTRALIA               Westerm Australia
# 37                   AUSTRALIA                        Victoria
# 38                   AUSTRALIA                        Victoria
# 35                         USA                          Hawaii
# 47                   AUSTRALIA               Western Australia
# 18                  COSTA RICA                    Cocos Island
# 19                   AUSTRALIA               Western Australia
# 7                          USA                         Florida
# 8                          USA                         Florida
# 9                          USA                         Florida
# 0                          USA                      California
# 21                   AUSTRALIA               Western Australia
# 10                   AUSTRALIA                      Queensland
# 39                SOUTH AFRICA                   KwaZulu-Natal
# 22                   AUSTRALIA               Western Australia
# 40                   AUSTRALIA                 New South Wales
# 23                    MALDIVES               Alifu Alifu Atoll
# 24                SOUTH AFRICA           Western Cape Province
# 11                         USA                  South Carolina
# 48               NEW CALEDONIA                         unknown
# 25                         USA                          Hawaii
# 1                          USA                         Georgia
# 41                   AUSTRALIA                        Victoria
# 42                   AUSTRALIA                 New South Wales
# 26                    THAILAND                         Hua Hin
# 27                      BRAZIL                      Pernambuco
# 28                   AUSTRALIA               Western Australia
# 29                   AUSTRALIA               Western Australia
# 36                   AUSTRALIA               Western Australia
# ...                        ...                             ...
# 6141                MARTINIQUE                         unknown
# 6142                       USA                         Florida
# 6143                       USA                          Hawaii
# 6144                    GUINEA                         unknown
# 6145                 GREENLAND                         unknown
# 6146                       USA                         unknown
# 6148                     SPAIN                         unknown
# 6149         MEDITERRANEAN SEA                         unknown
# 6153                    SWEDEN  Skagerrak arm of the North Sea
# 6150                   JAMAICA                         unknown
# 6151                       USA                   Massachusetts
# 6152                      CUBA                 Havana Province
# 6154                    PANAMA          Las Perlas archipelago
# 6155                   unknown                         unknown
# 6156                     ITALY                          Sicily
# 6158                    ROATAN                         unknown
# 6159                     ITALY                        Sardinia
# 6160                  BARBADOS                 Southwest coast
# 6161                    FRANCE                         unknown
# 6162                    FRANCE                    Côte d'Azur
# 6163                  BARBADOS                         unknown
# 6168                       USA                       New York
# 6165                   unknown                         unknown
# 6166                     INDIA                     West Bengal
# 6167                     INDIA                     West Bengal
# 6169                     INDIA                          Kerala
# 6170  Between PORTUGAL & INDIA                         unknown
# 6171                   unknown                         unknown
# 6172                    FRANCE               Nice & Marseilles
# 6173                 VENEZUELA     Magarita or Cubagua Islands
#
#                                                Location  \
# 17                                        Sai Noi Beach
# 14                                           Dugong Bay
# 37                                                Lorne
# 38                                             Winkipop
# 35                                          Kukio Beach
# 47                                             Cone Bay
# 18                                            Manuelita
# 19                                         Gearys Beach
# 7     Lighhouse Point Park, Ponce Inlet, Volusia County
# 8                          Cocoa Beach, Brevard  County
# 9                         Daytona Beach, Volusia County
# 0                           Oceanside, San Diego County
# 21                              Surfers Point, Prevelly
# 10                                      Cairns Aquarium
# 39                                               Durban
# 22                               South Point, Gracetown
# 40                   Little Congwong Beach, La Perouse
# 23                                            Madoogali
# 24                       Robberg Beach, Plettenberg Bay
# 11                    Isle of Palms,  Charleston County
# 48                                             Nouville
# 25               Shipwrecks Beach, Keoneloa Bay, Kauai
# 1                        St. Simon Island, Glynn County
# 41                                      Westernport Bay
# 42                                    Surf Beach, Kiama
# 26                                        Sai Noi Beach
# 27                                              Piedade
# 28                     Lefthanders, Margaret River Area
# 29                    Cobblestones, Margaret River Area
# 36                                       Waterman's Bay
# ...                                                 ...
# 6141                 Foundering of the privateer Holker
# 6142                  Pensacola Harbor, Escambia County
# 6143                                     Maliu, Hawai'i
# 6144                                            unknown
# 6145                                            unknown
# 6146                                         Damiscotte
# 6148                                 Guadalquivir River
# 6149                                            unknown
# 6153                                           Bohuslän
# 6150                                    Kingston Harbor
# 6151                                            unknown
# 6152                                      Havana Harbor
# 6154                              Taboga & Isla del Rey
# 6155                                       Carlisle Bay
# 6156                                  Strait of Messina
# 6158                                            unknown
# 6159                             Ponte della Maddelena,
# 6160                                       Carlisle Bay
# 6161                                               Nice
# 6162                                            Antibes
# 6163                                            unknown
# 6168                    Between Manhattan and The Bronx
# 6165                                            unknown
# 6166                                Hooghly River mouth
# 6167                                       Ganges Delta
# 6169                                       River Cochin
# 6170                                            unknown
# 6171                                            unknown
# 6172                                            unknown
# 6173                                            unknown
#
#                                                Activity  \
# 17                                             Swimming
# 14                                       Feeding sharks
# 37                                             Swimming
# 38                                              Surfing
# 35                              Stand-Up Paddleboarding
# 47                                              unknown
# 18                                         Scuba diving
# 19                                              Surfing
# 7                                               Fishing
# 8                                               Walking
# 9                                              Standing
# 0                                              Paddling
# 21                                              Surfing
# 10                                       Feeding sharks
# 39                                         Scuba Diving
# 22                                              Surfing
# 40                                             Swimming
# 23                                              Fishing
# 24                                        Paddle-skiing
# 11                                      Boogie boarding
# 48                                         Spearfishing
# 25                                        Body boarding
# 1                                              Standing
# 41                             Kayak fishing for sharks
# 42                                              Walking
# 26                                             Swimming
# 27                                             Swimming
# 28                                              Surfing
# 29                                              Surfing
# 36                                               Wading
# ...                                                 ...
# 6141                                            unknown
# 6142                                           Swimming
# 6143                                            Surfing
# 6144                                             Murder
# 6145                                            unknown
# 6146                                            Fishing
# 6148                                           Swimming
# 6149  Fell overboard from a frigate & was swallowed ...
# 6153                                            unknown
# 6150                                     Fell overboard
# 6151                                           Swimming
# 6152                                           Swimming
# 6154                                       Pearl diving
# 6155                                           Swimming
# 6156                                           Swimming
# 6158                                            unknown
# 6159                                           Swimming
# 6160                                           Swimming
# 6161                                            unknown
# 6162                                            Bathing
# 6163                                            Bathing
# 6168                                          Swimming
# 6165                                            unknown
# 6166                                             Wading
# 6167                                            unknown
# 6169  Ship lay at anchor & man was working on its ru...
# 6170  Man fell overboard from ship. Those on board t...
# 6171                                           Swimming
# 6172                                            unknown
# 6173                                       Pearl diving
#
#                                                    Name     Sex       Age  \
# 17                                               female        M  unknown
# 14                                      Melisa Brunning        F       34
# 37                                        Rob Crossland        M       69
# 38                                         Lachie Brown        M       18
# 35                                                 male        M       25
# 47                                                 male        M       18
# 18                                                 male        M       30
# 19                                          Adam Murray        M  unknown
# 7                                                  male        M       52
# 8                                             Cody High        M       15
# 9                                                  male        M       12
# 0                                           Julie Wolfe        F       57
# 21                                            Rob Bruce        M       60
# 10                                                 male        M       32
# 39                                          Elton Polly        M       38
# 22                                         Nathan Burch        M  unknown
# 40                                       Anna Shurapey         F       55
# 23                                        Ahmed Rasheed        M       32
# 24                                                 male        M       33
# 11                                         Trey de Boer        M       10
# 48                                                 male        M      40s
# 25                                     Dylan McWilliams        M       29
# 1                                       Adyson McNeely         F       11
# 41                                         Brett Palmer        M       34
# 42                                           Adam Hoare        M       35
# 26                                     Werner Danielsen        M       54
# 27                                        Pablo de Melo        M       34
# 28                                       Jason Longrass        M       41
# 29                                 Alejandro Travaglini        M       37
# 36                                 Luke Guy & Finn Bald        M       10
# ...                                                 ...      ...      ...
# 6141                                            unknown        M  unknown
# 6142                                       Joseph Feron        M  unknown
# 6143                                   Nu'u-anu-pa'a hu        M    young
# 6144                                      African slave        M  unknown
# 6145                            Occupants of skin boats  unknown  unknown
# 6146                                               male        M  unknown
# 6148                                               male        M  unknown
# 6149                                             sailor        M  unknown
# 6153                                          Fishermen        M  unknown
# 6150                                               male        M  unknown
# 6151                                               male        M  unknown
# 6152                                       Brook Watson        M       14
# 6154                                     African slaves        M  unknown
# 6155                                 2 impressed seamen        M  unknown
# 6156                                               male        M  unknown
# 6158                                      Philip Ashton        M  unknown
# 6159                                               male        M  unknown
# 6160  Samuel Jennings, a deserter from the British f...        M       19
# 6161                                              child        M  unknown
# 6162                                             seaman        M  unknown
# 6163                               seaman from the York        M  unknown
# 6168                                 Antony Van Corlear        M  unknown
# 6165                                            sailors        M  unknown
# 6166                                     Hindu pilgrims  unknown  unknown
# 6167                                      Indian people  unknown  unknown
# 6169                                               male        M  unknown
# 6170                                               male        M  unknown
# 6171                                               male        M  unknown
# 6172                              males (wearing armor)        M  unknown
# 6173                                       Indian slave        M  unknown
#
#                                                  Injury Fatal (Y/N)  \
# 17                                Minor injury to ankle           N
# 14      Shallow lacerations to finger PROVOKED INCIDENT           N
# 37    No injury, said to have been charged by sharks...           N
# 38                           Minor injury, ankle grazed           N
# 35                         Injuries to right leg & hand           N
# 47                                Injuries to right leg           N
# 18                      No injury, shark bit scuba gear           N
# 19                No injury, knocked off board by shark           N
# 7               Minor injury to foot. PROVOKED INCIDENT           N
# 8                                 Lower left leg bitten           N
# 9                                  Minor injury to foot           N
# 0     No injury to occupant, outrigger canoe and pad...           N
# 21                No injury, knocked off board by shark           N
# 10    Minor bite to hand by captive shark. PROVOKED ...           N
# 39     The shark & man simply collided; neither were...           N
# 22                      No injury, shark struck his leg           N
# 40                       Laceratons to right leg & foot           N
# 23                                   5-inch cut to hand           N
# 24                     No injury, shark bit hole in ski           N
# 11                 Injuries to lower right leg and foot           N
# 48                          Injuries to abdomen and arm           N
# 25                       Lacerations to right lower leg           N
# 1                            Minor injury to left thigh           N
# 41    Shark rammed kayak, no injury to occupant  PRO...           N
# 42             Puncture wounds to leff foot & lower leg           N
# 26                        Lacerations to foot and ankle           N
# 27    Multiple severe injuries to arms and leg, leg ...     unknown
# 28                            Laceration to right thigh           N
# 29                                  Lacerations to legs           N
# 36                               Minor injuries to legs           N
# ...                                                 ...         ...
# 6141              Many of the crew were taken by sharks           Y
# 6142                                              FATAL           Y
# 6143                         FATAL, buttock lacerated             Y
# 6144                                              FATAL           Y
# 6145                                              FATAL           Y
# 6146                                              FATAL           Y
# 6148                                              FATAL           Y
# 6149   "He was taken up alive and but little injured."            N
# 6153                                            unknown     UNKNOWN
# 6150                                              FATAL           Y
# 6151                                              FATAL           Y
# 6152  Right leg severed at knee.  In 1796 he became ...           N
# 6154                                              FATAL           Y
# 6155                                              FATAL           Y
# 6156                                              FATAL           Y
# 6158                                    Struck on thigh     unknown
# 6159  FATAL,  partial remains recovered from sharks...           Y
# 6160  Hand and foot severely bitten, surgically ampu...           N
# 6161                                              FATAL           Y
# 6162                                        Leg severed           N
# 6163                                              FATAL           Y
# 6168                                              FATAL           Y
# 6165                                            unknown     UNKNOWN
# 6166                                            unknown     UNKNOWN
# 6167                                            unknown     UNKNOWN
# 6169  Leg severed mid-thigh, hand severed, arm above...     UNKNOWN
# 6170                  FATAL. "Shark tore him to pieces.           Y
# 6171                                            unknown     UNKNOWN
# 6172                                            unknown     UNKNOWN
# 6173                                              FATAL           Y
#
#                Time                                           Species
# 17          unknown                                            unknown
# 14          unknown                              Tawny nurse shark, 2m
# 37            15h30                                        3.5 m shark
# 38            07h30                                        1.8 m shark
# 35            09h30                                   Tiger shark, 12'
# 47            08h00                                         Bull shark
# 18            10h40                                        Tiger shark
# 19            16h50                                            unknown
# 7           unknown                                    Lemon shark, 3'
# 8             17h00                                     Bull shark, 6'
# 9             14h00                                            unknown
# 0             18h00                                        White shark
# 21            09h30                                          3 m shark
# 10          Morning                                    Grey reef shark
# 39          unknown                                     Blacktip shark
# 22        Afternoon                                 White shark, 3.5 m
# 40      19h00, Dusk                Juvenile white shark,  2.7 to 3.2 m
# 23            21h50                                        Tiger shark
# 24            09h40                                 White shark, 2.5 m
# 11          unknown                                            unknown
# 48            15h30                                   Bull shark, 3 m
# 25          unknown                                           6' shark
# 1     14h00  -15h00                                            unknown
# 41            Night                                            unknown
# 42            16h00                                    Bull shark, 2 m
# 26          unknown                                Juvenile bull shark
# 27          unknown                                            unknown
# 28          unknown                                            unknown
# 29            08h00                                            unknown
# 36            17h35                                    Wobbegong shark
# ...             ...                                                ...
# 6141          06h00                                            unknown
# 6142        unknown                                            unknown
# 6143        unknown                                            unknown
# 6144        unknown                                            unknown
# 6145        unknown                                       White sharks
# 6146        unknown                                            unknown
# 6148        unknown                                            unknown
# 6149        unknown  "The fish was harpooned, dried, and presented ...
# 6153        unknown                                            unknown
# 6150        unknown                                            unknown
# 6151        unknown                                            unknown
# 6152        unknown                                            unknown
# 6154        unknown                                            unknown
# 6155        unknown                                            unknown
# 6156        unknown                                            unknown
# 6158        unknown                                            unknown
# 6159        unknown                       White shark, 1600-lb female
# 6160          Night                                            unknown
# 6161        unknown                                            unknown
# 6162        unknown                                        White shark
# 6163        unknown                                            unknown
# 6168        unknown                                            unknown
# 6165        unknown                                            unknown
# 6166        unknown                                            unknown
# 6167        unknown                                            unknown
# 6169        unknown                                            unknown
# 6170        unknown                                            unknown
# 6171        unknown                                            unknown
# 6172        unknown                              Possibly white sharks
# 6173        unknown                                            unknown
#
# [5627 rows x 15 columns]

# %%
df_analysis.isnull().sum()
# Out:
# Case Number    0
# Date           0
# Year           0
# Type           0
# Country        0
# Area           0
# Location       0
# Activity       0
# Name           0
# Sex            0
# Age            0
# Injury         0
# Fatal (Y/N)    0
# Time           0
# Species        0
# dtype: int64

# %%
#transformation of 'Fatal (Y/N)' column in int value 1-0
df_analysis['Fatal (Y/N)']=[re.sub(r'unknown','0', str(el).strip().upper()) for el in df_analysis['Fatal (Y/N)']]
df_analysis['Fatal (Y/N)']=df_analysis['Fatal (Y/N)'].replace('UNKNOWN','unknown')
df_analysis['Fatal (Y/N)']=df_analysis['Fatal (Y/N)'].replace('UNPROVOKED','1')
df_analysis['Fatal (Y/N)']=[re.sub(r'[N\n]{1}','0', str(el).strip()) for el in df_analysis['Fatal (Y/N)']]
df_analysis['Fatal (Y/N)']=df_analysis['Fatal (Y/N)'].replace('Y','1')
df_analysis['Fatal (Y/N)']=df_analysis['Fatal (Y/N)'].replace('y','1')
df_analysis['Fatal (Y/N)']=df_analysis['Fatal (Y/N)'].replace('M','0')
df_analysis['Fatal (Y/N)']=df_analysis['Fatal (Y/N)'].replace('2017','1')
df_analysis['Fatal (Y/N)']=df_analysis['Fatal (Y/N)'].replace('U0PROVOKED','1')

df_analysis["Fatal (Y/N)"].value_counts()
# Out:
# 0          4220
# 1          1324
# unknown      83
# Name: Fatal (Y/N), dtype: int64

# %%
#creation of 2 dummies variables for the value 'Fatal', 'NotFatal'
df_analysis['Fatal']=df_analysis['Fatal (Y/N)']
df_analysis['NotFatal']=df_analysis['Fatal (Y/N)'].replace('0','2')
df_analysis['NotFatal']=df_analysis['NotFatal'].replace('1','0')
df_analysis['NotFatal']=df_analysis['NotFatal'].replace('2','1')
df_analysis.head()
# Out:
#      Case Number                  Date  Year        Type    Country  \
# 17  2018.04.30.R  Reported 30-Apr-2018  2018  Unprovoked   THAILAND
# 14    2018.05.00              May 2018  2018    Provoked  AUSTRALIA
# 37  2018.03.09.b            9-Mar-2018  2018  Unprovoked  AUSTRALIA
# 38  2018.03.09.a            9-Mar-2018  2018  Unprovoked  AUSTRALIA
# 35    2018.03.31           31-Mar-2018  2018  Unprovoked        USA
#
#                  Area       Location                 Activity  \
# 17            Hua Hin  Sai Noi Beach                 Swimming
# 14  Westerm Australia     Dugong Bay           Feeding sharks
# 37           Victoria          Lorne                 Swimming
# 38           Victoria       Winkipop                  Surfing
# 35             Hawaii    Kukio Beach  Stand-Up Paddleboarding
#
#                Name Sex       Age  \
# 17           female    M  unknown
# 14  Melisa Brunning    F       34
# 37    Rob Crossland    M       69
# 38     Lachie Brown    M       18
# 35             male    M       25
#
#                                                Injury Fatal (Y/N)     Time  \
# 17                              Minor injury to ankle           0  unknown
# 14    Shallow lacerations to finger PROVOKED INCIDENT           0  unknown
# 37  No injury, said to have been charged by sharks...           0    15h30
# 38                         Minor injury, ankle grazed           0    07h30
# 35                       Injuries to right leg & hand           0    09h30
#
#                  Species  Fatal NotFatal
# 17                unknown     0        1
# 14  Tawny nurse shark, 2m     0        1
# 37            3.5 m shark     0        1
# 38            1.8 m shark     0        1
# 35       Tiger shark, 12'     0        1

# %%
df_analysis=df_analysis.drop('Fatal (Y/N)', axis=1)

# %%
#cleaning of the species column

df_analysis.columns
df_analysis['Species']=df_analysis['Species ']
df_analysis=df_analysis.drop('Species ',axis=1)

df_analysis['Species'].sample(50).value_counts()


def fn2(x):
    x=str(x).upper()
    if len(re.findall(r'[A-Z]+\sSHARK',x))>0:
        return re.findall(r'[A-Z]+\sSHARK',x)[0].split('SHARK')[0].lower().strip()
    else:
        return 'unknown'
    
df_analysis['Species1']=df_analysis['Species'].apply(fn2)

# %%
#KEEP ONLY THE 5 MOST FREQUENT SPECIES

df_analysis['Species1']=df_analysis['Species1'].replace('m','unknown')
df_analysis['Species1'].value_counts()
df_analysis['Species1'] = pd.Series(['unknown' if len(str(el))<=2  else str(el)  for el in df_analysis['Species1'] ])

# %%
df_analysis['Species1'].value_counts()
df_analysis['Species']=df_analysis['Species1']
df_analysis=df_analysis.drop('Species1',axis=1)

# %%
df_analysis.head()
# Out:
#      Case Number                  Date  Year        Type    Country  \
# 17  2018.04.30.R  Reported 30-Apr-2018  2018  Unprovoked   THAILAND
# 14    2018.05.00              May 2018  2018    Provoked  AUSTRALIA
# 37  2018.03.09.b            9-Mar-2018  2018  Unprovoked  AUSTRALIA
# 38  2018.03.09.a            9-Mar-2018  2018  Unprovoked  AUSTRALIA
# 35    2018.03.31           31-Mar-2018  2018  Unprovoked        USA
#
#                  Area       Location                 Activity  \
# 17            Hua Hin  Sai Noi Beach                 Swimming
# 14  Westerm Australia     Dugong Bay           Feeding sharks
# 37           Victoria          Lorne                 Swimming
# 38           Victoria       Winkipop                  Surfing
# 35             Hawaii    Kukio Beach  Stand-Up Paddleboarding
#
#                Name Sex       Age  \
# 17           female    M  unknown
# 14  Melisa Brunning    F       34
# 37    Rob Crossland    M       69
# 38     Lachie Brown    M       18
# 35             male    M       25
#
#                                                Injury     Time Fatal NotFatal  \
# 17                              Minor injury to ankle  unknown     0        1
# 14    Shallow lacerations to finger PROVOKED INCIDENT  unknown     0        1
# 37  No injury, said to have been charged by sharks...    15h30     0        1
# 38                         Minor injury, ankle grazed    07h30     0        1
# 35                       Injuries to right leg & hand    09h30     0        1
#
#       Species
# 17      tiger
# 14   blacktip
# 37    unknown
# 38  wobbegong
# 35      small

# %%
#leaning of the 
def fn3(x):
    x=str(x).upper()
    if len(re.findall(r'[A-Za-z]{3}-?',x))>0:
        return re.findall(r'[A-Za-z]{3}-?',x)[0].split('-')[0].lower().strip()
    else:
        return 'unknown'
    
df_analysis['Date']=df_analysis['Date'].apply(fn3)
df_analysis['Date']=df_analysis['Date'].replace('rep','sep')

df_analysis['Date']=df_analysis['Date'].replace(to_replace=['dec','jan','feb'], value ='win')
df_analysis['Date']=df_analysis['Date'].replace(to_replace=['sep','oct','nov'], value ='aut')
df_analysis['Date']=df_analysis['Date'].replace(to_replace=['aug','jun','jul'], value ='sum')
df_analysis['Date']=df_analysis['Date'].replace(to_replace=['may','mar','apr'], value ='spr')

filter1=df_analysis['Date'].isin(['win','sum','aut','spr'])
filter1=~filter1
df_analysis.loc[filter1,'Date']='unk'
df_analysis['Date'].value_counts()
df_analysis['Season']=df_analysis['Date']
df_analysis=df_analysis.drop('Date',axis=1)

# %%
df_analysis.to_csv("/Users/silviaserafini/ironhack/PROGETTI/SharksData/sharks_clean.csv")

# %%
df_analysis['Country'].value_counts().head(14)
# Out:
# USA                 2020
# AUSTRALIA           1200
# SOUTH AFRICA         506
# PAPUA NEW GUINEA     129
# NEW ZEALAND          115
# BRAZIL               102
# BAHAMAS              101
# MEXICO                77
# FIJI                  59
# REUNION               58
# ITALY                 57
# PHILIPPINES           57
# NEW CALEDONIA         52
# CUBA                  42
# Name: Country, dtype: int64
